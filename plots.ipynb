# %%
import matplotlib.pyplot as plt

# Data
neurons_per_layer = [0,4, 8, 16, 32]
micrograd_times = [0, 0.094,0.22,0.58,1.44]
cudagrad_times = [0, 477.16,878.975,1757.95,3817.28]

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(neurons_per_layer, micrograd_times, marker='o', label='Micrograd')
plt.plot(neurons_per_layer, cudagrad_times, marker='s', label='CUDAGrad 1D')

# Labels and Title
plt.xlabel('No. of Neurons per Layer')
plt.ylabel('Time Taken in Seconds')
plt.title('Performance Comparison: Micrograd vs CUDAGrad 1D')
plt.legend()
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
neurons_per_layer = [4, 8, 16, 32]
micrograd_times = [0.094,0.22,0.58,1.44]
cudagrad_times = [477.16,878.975,1757.95,3817.28]

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(neurons_per_layer, micrograd_times, marker='o', label='Micrograd')
plt.plot(neurons_per_layer, cudagrad_times, marker='s', label='CUDAGrad 1D')

# Labels and Title
plt.xlabel('No. of Neurons per Layer')
plt.ylabel('Time Taken in Seconds')
plt.title('Performance Comparison: Micrograd vs CUDAGrad 1D')
plt.yscale('log')  # Set y-axis to log scale
plt.xscale('log')
plt.legend()
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
neurons_per_layer = [0,4, 8, 16, 32, 64, 128, 256, 512]
micrograd_times = [0, 0.094, 0.22, 0.58, 1.44, 3.23, 6.68, 13.7, 28.02]
cudagrad_times = [0, 0.15, 0.16, 0.16, 0.16, 0.18, 0.17, 0.17, 0.17]

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(neurons_per_layer, micrograd_times, marker='o', label='Micrograd')
plt.plot(neurons_per_layer, cudagrad_times, marker='s', label='CUDAGrad 2D')

# Labels and Title
plt.xlabel('No. of Neurons per Layer')
plt.ylabel('Time Taken in Seconds')
plt.title('Performance Comparison: Micrograd vs CUDAGrad 2D')
plt.legend()
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
neurons_per_layer = [4, 8, 16, 32, 64, 128, 256, 512]
micrograd_times = [0.094, 0.22, 0.58, 1.44, 3.23, 6.68, 13.7, 28.02]
cudagrad_times = [0.15, 0.16, 0.16, 0.16, 0.18, 0.17, 0.17, 0.17]

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(neurons_per_layer, micrograd_times, marker='o', label='Micrograd')
plt.plot(neurons_per_layer, cudagrad_times, marker='s', label='CUDAGrad 2D')

# Labels and Title
plt.xlabel('No. of Neurons per Layer')
plt.ylabel('Time Taken in Seconds')
plt.title('Performance Comparison: Micrograd vs CUDAGrad 2D')
plt.yscale('log')  # Set y-axis to log scale
plt.xscale('log')
plt.legend()
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
neurons_per_layer = [4, 8, 16, 32, 64, 128, 256, 512]
speedup = [0.626666666666667,1.375, 3.625, 9, 17.9444444444444, 39.2941176470588, 80.5882352941176, 164.823529411765]


# Plotting
plt.figure(figsize=(8, 6))
plt.plot(neurons_per_layer, speedup, marker='o', label='Speedup')
# plt.plot(neurons_per_layer, cudagrad_times, marker='s', label='CUDAGrad 2D')

# Labels and Title
plt.xlabel('No. of Neurons per Layer')
plt.ylabel('Observed Speedup')
plt.title('Speedup vs No. of Neurons per Layer')
# plt.yscale('log')  # Set y-axis to log scale
# plt.xscale('log')
plt.legend()
plt.grid(True)

plt.show()
