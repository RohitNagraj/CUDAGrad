# %%
import pandas as pd

# %%
df = pd.read_csv('../data/higgs/higgs.csv', nrows=1024, header=None)

# %%
df
# Out:
#        0         1         2         3         4         5         6   \
# 0     1.0  0.869293 -0.635082  0.225690  0.327470 -0.689993  0.754202
# 1     1.0  0.907542  0.329147  0.359412  1.497970 -0.313010  1.095531
# 2     1.0  0.798835  1.470639 -1.635975  0.453773  0.425629  1.104875
# 3     0.0  1.344385 -0.876626  0.935913  1.992050  0.882454  1.786066
# 4     1.0  1.105009  0.321356  1.522401  0.882808 -1.205349  0.681466
# ...   ...       ...       ...       ...       ...       ...       ...
# 1019  1.0  1.562898 -1.397699  0.234568  0.741629  0.282596  1.324640
# 1020  1.0  0.577943  1.508624  0.206270  1.196517  1.188856  1.189153
# 1021  0.0  1.840706  2.155339  0.303371  0.209071  0.282164  1.314747
# 1022  0.0  0.871306 -1.296407  1.015813  0.655320 -1.494430  0.565491
# 1023  0.0  0.663225 -0.509440  0.123041  1.114499  0.846379  0.808342
#
#             7         8         9   ...        19        20        21  \
# ...

# %%
df[0].value_counts()
# Out:
# 0
# 1.0    551
# 0.0    473
# Name: count, dtype: int64

# %%
df.drop(columns=[0]).to_numpy().shape
# Out:
# (1024, 28)

# %%
df[0].to_numpy().shape
# Out:
# (1024,)

# %%
from micrograd.nn import MLP
